# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3
# Out:
# 5

# %%
17%3
# Out:
# 2

# %%
# Round

round(17/3)
# Out:
# 6

# %%
round(17/3,2)

# %% [markdown]
# Truncar elimina los decimales sin redondear

# %%
from math import trunc

trunc(17/3)
# Out:
# 5

# %% [markdown]
# Redondeo hacia arriba

# %%
from math import ceil

ceil(17/3)
# Out:
# 6

# %% [markdown]
# Redondear a la baja

# %%
from math import floor

floor(17/3)
# Out:
# 5
